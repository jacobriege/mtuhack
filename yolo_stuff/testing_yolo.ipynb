# %%
from pathlib import Path
from ultralytics import YOLO
from yolo_functions import *

# %% [markdown]
# # Setup

# %%
ppe_model, face_model = load_yolo_models(
    path_to_ppe_model = 'models/ppe_yolo26n.pt',
    path_to_face_model = 'models/face_detection_yolo11n.pt'
)

# %% [markdown]
# # Script

# %%
# detections = process_ppe_images(
#     model=ppe_model,
#     input_dir="test_images",
#     output_dir="result_images",
#     conf=0.5
# )

# %%
# detections = process_ppe_images_filtered(
#     model=ppe_model,
#     input_dir="test_images",
#     output_dir="result_images",
#     conf=0.5,
#     wanted_labels={"Hardhat", "Safety Vest", "Goggles", "Person"}
# )

# %%
# face_detections = process_face_images(
#     model=face_model,
#     input_dir="test_images",
#     output_dir="result_images",
#     conf=0.5
# )

# %%
combined_results = process_combined_ppe_and_face(
    ppe_model=ppe_model,
    face_model=face_model,
    input_dir="test_images",
    output_dir="result_images",
    conf_ppe=0.5,
    conf_face=0.5,
    horizontal_tolerance_degrees=20
)
